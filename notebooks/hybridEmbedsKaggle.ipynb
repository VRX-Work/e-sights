# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sample/search.npy
# /kaggle/input/sample/sample 1.csv

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
emails = pd.read_csv('/kaggle/input/sample/sample 1.csv')
emails.head()
# Out:
#                       Subject            From              To        Date  \
# 0              Project Update  alice@orgA.com    bob@orgB.com  2024-01-02
# 1          Re: Project Update    bob@orgB.com  alice@orgA.com  2024-01-03
# 2  Confidential: Design Specs  alice@orgA.com    bob@orgB.com  2024-01-04
# 3           HR Policy Changes     hr@orgA.com    all@orgA.com  2024-01-05
# 4  Quick Question About Specs    bob@orgB.com  alice@orgA.com  2024-01-06
#
#                                                 Body
# 0  Hi Bob, I wanted to give you a quick update on...
# 1  Hey Alice, Thanks for the update! I'm really l...
# 2  Bob, I've attached some preliminary design spe...
# 3  Dear Team, We have updated our HR policies reg...
# 4  Hi Alice, I had a question about the specs you...

# %%
emails_formatted = emails.to_dict(orient='records') # Array of Dict
emails_formatted
# Out:
# [{'Subject': 'Project Update',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-02',
#   'Body': "Hi Bob, I wanted to give you a quick update on our current project. Things are progressing well, and we're nearing the final stages of development. I think you'll be impressed with what we have in store. Let's catch up soon. Best, Alice"},
#  {'Subject': 'Re: Project Update',
#   'From': 'bob@orgB.com',
#   'To': 'alice@orgA.com',
#   'Date': '2024-01-03',
#   'Body': "Hey Alice, Thanks for the update! I'm really looking forward to seeing the final product. Let's schedule a meeting next week to discuss potential collaborations. Cheers, Bob"},
#  {'Subject': 'Confidential: Design Specs',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-04',
#   'Body': "Bob, I've attached some preliminary design specs for the upcoming project. Please keep this under wraps as we are still finalizing details internally. Your insights would be invaluable, but let's keep this between us for now. Regards, Alice"},
#  {'Subject': 'HR Policy Changes',
#   'From': 'hr@orgA.com',
#   'To': 'all@orgA.com',
#   'Date': '2024-01-05',
#   'Body': 'Dear Team, We have updated our HR policies regarding remote work and vacation days. Please review the attached document and reach out if you have any questions. Best, HR Team'},
#  {'Subject': 'Quick Question About Specs',
#   'From': 'bob@orgB.com',
#   'To': 'alice@orgA.com',
#   'Date': '2024-01-06',
#   'Body': "Hi Alice, I had a question about the specs you sent over. Are there any specific features that you think might be a game changer? I'd love to hear your thoughts. Thanks! Bob"},
#  {'Subject': 'Re: Quick Question About Specs',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-07',
#   'Body': 'Hey Bob, Absolutely! There are a few features that we believe will set us apart in the market. I can share more details if you promise to keep it discreet. Best, Alice'},
#  {'Subject': 'Meeting Reminder: Project Sync-Up',
#   'From': 'carol@orgA.com',
#   'To': 'team@orgA.com',
#   'Date': '2024-01-08',
#   'Body': "Hi Team, Just a reminder about our project sync-up tomorrow at 10 AM. Please come prepared with your updates and any blockers you're facing. Thanks, Carol"},
#  {'Subject': 'Re: Meeting Reminder: Project Sync-Up',
#   'From': 'dave@orgA.com',
#   'To': 'carol@orgA.com',
#   'Date': '2024-01-09',
#   'Body': "Hi Carol, Looking forward to the meeting! I've been working on some innovative solutions that could enhance our project's performance metrics. I'll share them during the meeting. Best, Dave"},
#  {'Subject': 'Insider Info Needed ASAP',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-10',
#   'Body': "Bob, I need your expertise on something urgent. Can we discuss the latest market trends? I believe they could impact our upcoming launch significantly. Let me know when you're free. Alice"},
#  {'Subject': 'Re: Insider Info Needed ASAP',
#   'From': 'bob@orgB.com',
#   'To': 'alice@orgA.com',
#   'Date': '2024-01-11',
#   'Body': "Sure Alice, I can provide some insights on that. Let's chat later today? I have some data that might be useful for your strategy. Cheers, Bob"},
#  {'Subject': 'Team Outing Plans!',
#   'From': 'emily@orgA.com',
#   'To': 'all@orgA.com',
#   'Date': '2024-01-12',
#   'Body': "Hi Everyone, We're planning a team outing next month! Please fill out the attached survey to help us decide on activities and dates. Looking forward to everyone's input! Best, Emily"},
#  {'Subject': 'Project Milestone Achieved!',
#   'From': 'frank@orgA.com',
#   'To': 'team@orgA.com',
#   'Date': '2024-01-13',
#   'Body': "Dear Team, I'm thrilled to announce that we have achieved a significant milestone in our project! Great job everyone! Let's keep up the momentum as we move into the next phase. Cheers, Frank"},
#  {'Subject': 'Market Analysis Request',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-14',
#   'Body': 'Bob, Could you send me that market analysis report we discussed last week? It would really help us align our strategies moving forward. Thanks! Alice'},
#  {'Subject': 'Re: Market Analysis Request',
#   'From': 'bob@orgB.com',
#   'To': 'alice@orgA.com',
#   'Date': '2024-01-15',
#   'Body': "Hi Alice, Absolutely! I'll send it over shortly. It contains some sensitive information, so please handle it with care. Best, Bob"},
#  {'Subject': 'Reminder: Compliance Training Tomorrow!',
#   'From': 'hr@orgA.com',
#   'To': 'all@orgA.com',
#   'Date': '2024-01-16',
#   'Body': 'Dear Team, This is a reminder for compliance training scheduled for tomorrow at 2 PM. Attendance is mandatory. Please be on time. Thank you! HR Team'},
#  {'Subject': 'Re: Compliance Training Tomorrow! ',
#   'From': 'jane@orgA.com ',
#   'To': 'hr@orgA.com ',
#   'Date': '2024-01-17 ',
#   'Body': "Hi HR Team, I won't be able to attend due to a scheduling conflict. Is there any way I can catch up on what I missed? Thanks, jane "},
#  {'Subject': 'Confidential Insights Needed ',
#   'From': 'alice@orgA.com ',
#   'To': 'bob@orgB.com ',
#   'Date': '2024-01-18 ',
#   'Body': "Hey Bob, I'm looking for some confidential insights regarding competitor strategies in light of recent market shifts. Your perspective would be invaluable here—let's keep this off the record, okay? Best, alice "},
#  {'Subject': 'Re: Confidential Insights Needed ',
#   'From': 'bob@orgB.com ',
#   'To': 'alice@orgA.com ',
#   'Date': '2024-01-19 ',
#   'Body': "Of course, Alice! I'll compile some thoughts and send them your way shortly. Let's ensure we maintain discretion as always. Cheers, bob "},
#  {'Subject': 'Project Feedback Request ',
#   'From': 'carol@orgA.com ',
#   'To': 'team@orgA.com ',
#   'Date': '2024-01-20 ',
#   'Body': 'Hi Team, As we wrap up this phase of the project, I would appreciate your feedback on what worked well and what could be improved for next time. Please reply by Friday so we can incorporate your suggestions moving forward. Thanks! carol '},
#  {'Subject': 'Re: Project Feedback Request ',
#   'From': 'dave@orgA.com ',
#   'To': 'carol@orgA.com ',
#   'Date': '2024-01-21 ',
#   'Body': 'Hi Carol, I think communication was key in our success this phase. However, I believe we could improve on documentation processes for future projects. Happy to discuss further! dave '},
#  {'Subject': 'Urgent: Need Your Thoughts ',
#   'From': 'alice@orgA.com ',
#   'To': 'bob@orgB.com ',
#   'Date': '2024-01-22 ',
#   'Body': 'Bob, I need your thoughts on some sensitive topics regarding our upcoming launch strategy—specifically how we can position ourselves against competitors without drawing too much attention. Can we chat later today? alice '},
#  {'Subject': 'Re: Urgent: Need Your Thoughts ',
#   'From': 'bob@orgB.com ',
#   'To': 'alice@orgA.com ',
#   'Date': '2024-01-23 ',
#   'Body': "Absolutely, Alice! Let's discuss this in detail later today; it's crucial that we approach this carefully given the stakes involved. bob "},
#  {'Subject': 'Weekly Check-In Reminder ',
#   'From': 'emily@orgA.com ',
#   'To': 'team@orgA.com ',
#   'Date': '2024-01-24 ',
#   'Body': "Hi Team, Just a reminder about our weekly check-in tomorrow at 11 AM. Bring any updates or concerns you'd like to discuss with the group! Looking forward to seeing everyone there! emily "},
#  {'Subject': 'Re: Weekly Check-In Reminder ',
#   'From': 'frank@orgA.com ',
#   'To': 'emily@orgA.com ',
#   'Date': '2024-01-25 ',
#   'Body': "Thanks Emily! I'll make sure to prepare my updates regarding our progress on the current project phase—excited to share what we've accomplished so far! frank "},
#  {'Subject': 'Final Review Needed Before Launch ',
#   'From': 'alice@orgA.com ',
#   'To': 'bob@orgB.com ',
#   'Date': '2024-01-26 ',
#   'Body': "Hey Bob, We're in the final review stages before launch and need your keen eye on a few details—especially regarding competitive positioning and market entry tactics. Can you help? Let's keep it discreet as always! alice "},
#  {'Subject': 'Re: Final Review Needed Before Launch ',
#   'From': 'bob@orgB.com ',
#   'To': 'alice@orgA.com ',
#   'Date': '2024-01-27 ',
#   'Body': "Of course, Alice! I'll review everything and provide my feedback by tomorrow morning—let's ensure we're aligned for a successful launch! bob "},
#  {'Subject': 'Innovation Brainstorming Session Invite ',
#   'From': 'carol@orgA.com ',
#   'To': 'team@orgA.com ',
#   'Date': '2024-01-28 ',
#   'Body': 'Hello Team, You are invited to an innovation brainstorming session next week where we will explore new ideas for enhancing our project outcomes. Your input is vital! Please RSVP by Wednesday. best, carol '}]

# %% [markdown]
# ### Utility Functions

# %%
def strip_email(email):
    for key in email:
        if isinstance(email[key], str):
            email[key] = email[key].strip()
    return email
    
def index_emails(emails):
    for idx, email in enumerate(emails):
        emails[idx] = strip_email(emails[idx])

    return emails

# %%
emails_formatted = index_emails(emails_formatted)

# %% [markdown]
# ## Semantic Search using FAISS

# %%
# !pip install faiss-cpu sentence-transformers
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /opt/conda/lib/python3.10/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from faiss-cpu) (21.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.46.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (2.4.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->faiss-cpu) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 53.6 MB/s eta 0:00:00:00:0100:01
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.7 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu, sentence-transformers
# Successfully installed faiss-cpu-1.9.0.post1 sentence-transformers-3.3.1

# %%
documents = [f"{item['Subject']} {item['Body']}" for item in emails_formatted]

# %%
# import faiss
# from sentence_transformers import SentenceTransformer
# model = SentenceTransformer("all-mpnet-base-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embeddings = model.encode(documents)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Create a FAISS index
dimension = embeddings.shape[1]  # Dimensionality of the embeddings
index = faiss.IndexFlatL2(dimension)  # Using L2 distance for similarity search

# Add embeddings to the index
index.add(embeddings)

# %%
# Define your search query
query = "Sharing secret information"
query_embedding = model.encode([query]).astype('float32')

# Search the index for the top k similar documents
k = 5  # Number of nearest neighbors to retrieve
D, I = index.search(query_embedding, k)  # D: distances, I: indices of nearest neighbors

# Retrieve results based on indices
results = [emails_formatted[i] for i in I[0]]
results
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'Subject': 'Confidential Insights Needed',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-18',
#   'Body': "Hey Bob, I'm looking for some confidential insights regarding competitor strategies in light of recent market shifts. Your perspective would be invaluable here—let's keep this off the record, okay? Best, alice"},
#  {'Subject': 'Urgent: Need Your Thoughts',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-22',
#   'Body': 'Bob, I need your thoughts on some sensitive topics regarding our upcoming launch strategy—specifically how we can position ourselves against competitors without drawing too much attention. Can we chat later today? alice'},
#  {'Subject': 'Insider Info Needed ASAP',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-10',
#   'Body': "Bob, I need your expertise on something urgent. Can we discuss the latest market trends? I believe they could impact our upcoming launch significantly. Let me know when you're free. Alice"},
#  {'Subject': 'Final Review Needed Before Launch',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-26',
#   'Body': "Hey Bob, We're in the final review stages before launch and need your keen eye on a few details—especially regarding competitive positioning and market entry tactics. Can you help? Let's keep it discreet as always! alice"},
#  {'Subject': 'Confidential: Design Specs',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-04',
#   'Body': "Bob, I've attached some preliminary design specs for the upcoming project. Please keep this under wraps as we are still finalizing details internally. Your insights would be invaluable, but let's keep this between us for now. Regards, Alice"}]

# %%
len(results)
# Out:
# 5

# %% [markdown]
# ## Intersection between Elastic Search and Semantic Serach

# %%
elastic_array =  np.load('/kaggle/input/sample/search.npy',allow_pickle=True)
semantic_results = np.array(results)
semantic_results = semantic_results.tolist()
#semantic_results
semantic_df = pd.DataFrame(semantic_results)
semantic_df
# Out:
#                              Subject            From            To  \
# 0       Confidential Insights Needed  alice@orgA.com  bob@orgB.com
# 1         Urgent: Need Your Thoughts  alice@orgA.com  bob@orgB.com
# 2           Insider Info Needed ASAP  alice@orgA.com  bob@orgB.com
# 3  Final Review Needed Before Launch  alice@orgA.com  bob@orgB.com
# 4         Confidential: Design Specs  alice@orgA.com  bob@orgB.com
#
#          Date                                               Body
# 0  2024-01-18  Hey Bob, I'm looking for some confidential ins...
# 1  2024-01-22  Bob, I need your thoughts on some sensitive to...
# 2  2024-01-10  Bob, I need your expertise on something urgent...
# 3  2024-01-26  Hey Bob, We're in the final review stages befo...
# 4  2024-01-04  Bob, I've attached some preliminary design spe...

# %%
elastic_results = [entry['_source'] for entry in elastic_array]
elastic_df = pd.DataFrame(elastic_results)
#elastic_results
elastic_df
# Out:
#                                  Subject            From              To  \
# 0           Confidential Insights Needed  alice@orgA.com    bob@orgB.com
# 1             Confidential: Design Specs  alice@orgA.com    bob@orgB.com
# 2               Project Feedback Request  carol@orgA.com   team@orgA.com
# 3         Re: Quick Question About Specs  alice@orgA.com    bob@orgB.com
# 4      Final Review Needed Before Launch  alice@orgA.com    bob@orgB.com
# 5                Market Analysis Request  alice@orgA.com    bob@orgB.com
# 6       Re: Confidential Insights Needed    bob@orgB.com  alice@orgA.com
# 7                         Project Update  alice@orgA.com    bob@orgB.com
# 8  Re: Meeting Reminder: Project Sync-Up   dave@orgA.com  carol@orgA.com
# 9  Re: Final Review Needed Before Launch    bob@orgB.com  alice@orgA.com
#
#          Date                                               Body
# 0  2024-01-18  Hey Bob, I'm looking for some confidential ins...
# 1  2024-01-04  Bob, I've attached some preliminary design spe...
# 2  2024-01-20  Hi Team, As we wrap up this phase of the proje...
# 3  2024-01-07  Hey Bob, Absolutely! There are a few features ...
# 4  2024-01-26  Hey Bob, We're in the final review stages befo...
# 5  2024-01-14  Bob, Could you send me that market analysis re...
# 6  2024-01-19  Of course, Alice! I'll compile some thoughts a...
# 7  2024-01-02  Hi Bob, I wanted to give you a quick update on...
# 8  2024-01-09  Hi Carol, Looking forward to the meeting! I've...
# 9  2024-01-27  Of course, Alice! I'll review everything and p...

# %%
hybrid_df = pd.merge(semantic_df, elastic_df, on=['Subject', 'From', 'To', 'Date', 'Body'], how='inner')

# %%
hybrid_df.to_dict(orient='records')
# Out:
# [{'Subject': 'Confidential Insights Needed',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-18',
#   'Body': "Hey Bob, I'm looking for some confidential insights regarding competitor strategies in light of recent market shifts. Your perspective would be invaluable here—let's keep this off the record, okay? Best, alice"},
#  {'Subject': 'Final Review Needed Before Launch',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-26',
#   'Body': "Hey Bob, We're in the final review stages before launch and need your keen eye on a few details—especially regarding competitive positioning and market entry tactics. Can you help? Let's keep it discreet as always! alice"},
#  {'Subject': 'Confidential: Design Specs',
#   'From': 'alice@orgA.com',
#   'To': 'bob@orgB.com',
#   'Date': '2024-01-04',
#   'Body': "Bob, I've attached some preliminary design specs for the upcoming project. Please keep this under wraps as we are still finalizing details internally. Your insights would be invaluable, but let's keep this between us for now. Regards, Alice"}]

# %% [markdown]
# ## Stella

# %%
# ！The default dimension is 1024, if you need other dimensions, please clone the model and modify `modules.json` to replace `2_Dense_1024` with another dimension, e.g. `2_Dense_256` or `2_Dense_8192` !
import faiss
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("dunzhang/stella_en_1.5B_v5", trust_remote_code=True).cuda()
doc_embeddings = model.encode(documents)
# Out:
# modules.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/174k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# modeling_qwen.py:   0%|          | 0.00/65.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/dunzhang/stella_en_1.5B_v5:
# - modeling_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/6.17G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/10.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/dunzhang/stella_en_1.5B_v5:
# - tokenization_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/370 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# 2_Dense_1024/config.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.30M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/6.30M [00:00<?, ?B/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
